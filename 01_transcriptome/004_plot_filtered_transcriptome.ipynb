# %% [markdown]
# 批量画图

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import traceback

# 不需要分析的列名列表
EXCLUDE_COLUMNS = [
    'nodes', 'isoform_id', 'identity', 'target', 'uniprotKB_pfam', 
    'uniprotKB_EC_number', 'uniprotKB_clan', 'uniprotKB_EC_class',
    'proteinVec_Filename', 'proteinVec_Pfam', 
    'proteinVec_Gene_Ontology_(biological_process)',
    'proteinVec_Gene_Ontology_(molecular_function)', 
    'proteinVec_Gene_Ontology_(cellular_component)',
    'proteinVec_Gene3D', 'proteinVec_EC_number', 'uniprotKB',
    'proteome_Gene_Name', 'gene_symbol', 'Row.names', 'transcript_id'
]

# 创建输出目录
output_dir = 'check_column_distribution'
os.makedirs(output_dir, exist_ok=True)

# 读取数据
df = pd.read_csv('021.filtered_no_AFDB_sqanti3_classifcation_90928.tsv', sep='\t')

# 检查已经生成的图片
existing_plots = {f.split('_distribution.png')[0] for f in os.listdir(output_dir) if f.endswith('_distribution.png')}
print(f"已经成功生成的图片数量: {len(existing_plots)}")

# 对每一列进行分析
for column in df.columns:
    try:
        # 跳过不需要分析的列
        if column in EXCLUDE_COLUMNS:
            continue
            
        # 跳过已经成功生成的列
        if column in existing_plots:
            print(f"跳过已处理的列: {column}")
            continue
            
        print(f"\n开始处理列: {column}")
        print(f"数据类型: {df[column].dtype}")
        print(f"唯一值数量: {df[column].nunique()}")
        print(f"非空值数量: {df[column].count()}")
        
        # 检查数据大小，如果唯一值太多就跳过
        if df[column].nunique() > 1000:
            print(f"跳过列 {column}: 唯一值数量({df[column].nunique()})太多")
            continue
            
        plt.figure(figsize=(10, 6))
        
        # 判断列的数据类型
        if df[column].dtype in ['object', 'string']:  # 字符串类型
            print("处理类别型数据...")
            # 如果唯一值太多，只显示top N个
            value_counts = df[column].value_counts()
            if len(value_counts) > 20:
                value_counts = value_counts.head(20)
                print(f"警告: {column} 包含超过20个唯一值，只显示前20个")
            
            # 检查数据是否为空
            if len(value_counts) == 0:
                print(f"跳过列 {column}: 没有有效数据")
                plt.close()
                continue
                
            plt.pie(value_counts.values, labels=value_counts.index, autopct='%1.1f%%')
            plt.title(f'Distribution of {column} (Categorical)')
            
        else:  # 数值类型
            print("处理数值型数据...")
            # 移除可能的无限值和空值
            data = df[column].replace([np.inf, -np.inf], np.nan).dropna()
            
            # 检查是否有足够的数据
            if len(data) == 0:
                print(f"跳过列 {column}: 没有有效数值数据")
                plt.close()
                continue
                
            # 检查数据范围
            print(f"数据范围: {data.min()} to {data.max()}")
            
            # 绘制分布图
            sns.histplot(data=data, bins=30, kde=True)
            plt.title(f'Distribution of {column} (Numerical)')
            plt.xlabel(column)
            plt.ylabel('Count')
        
        # 保存图片前先检查图形大小
        fig = plt.gcf()
        fig_size = fig.get_size_inches()
        dpi = fig.get_dpi()
        pixel_size = (fig_size[0] * dpi, fig_size[1] * dpi)
        
        # 如果图片尺寸太大就跳过
        if pixel_size[0] > 65000 or pixel_size[1] > 65000:
            print(f"跳过列 {column}: 图片尺寸太大 ({pixel_size[0]}x{pixel_size[1]} pixels)")
            plt.close()
            continue
        
        # 保存图片
        plt.tight_layout()
        save_path = os.path.join(output_dir, f'{column}_distribution.png')
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.close()
        
        print(f"成功保存图片: {save_path}")
        
    except Exception as e:
        print(f"\n处理列 {column} 时出错:")
        print(f"错误类型: {type(e).__name__}")
        print(f"错误信息: {str(e)}")
        plt.close()  # 确保关闭当前图形
        continue  # 继续处理下一列

print("\n处理完成！")
# Out:
# 已经成功生成的图片数量: 0
#
# 开始处理列: chrom
# 数据类型: object
# 唯一值数量: 25
# 非空值数量: 90929
# 处理类别型数据...
# 警告: chrom 包含超过20个唯一值，只显示前20个
# 成功保存图片: check_column_distribution/chrom_distribution.png
#
# 开始处理列: strand
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/strand_distribution.png
#
# 开始处理列: length
# 数据类型: float64
# 唯一值数量: 8093
# 非空值数量: 90929
# 跳过列 length: 唯一值数量(8093)太多
#
# 开始处理列: exons
# 数据类型: float64
# 唯一值数量: 74
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: 1.0 to 78.0
# 成功保存图片: check_column_distribution/exons_distribution.png
#
# 开始处理列: structural_category
# 数据类型: object
# 唯一值数量: 8
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/structural_category_distribution.png
#
# 开始处理列: associated_gene
# 数据类型: object
# 唯一值数量: 14384
# 非空值数量: 90929
# 跳过列 associated_gene: 唯一值数量(14384)太多
#
# 开始处理列: associated_transcript
# 数据类型: object
# 唯一值数量: 25996
# 非空值数量: 90929
# 跳过列 associated_transcript: 唯一值数量(25996)太多
#
# 开始处理列: ref_length
# 数据类型: float64
# 唯一值数量: 8110
# 非空值数量: 90920
# 跳过列 ref_length: 唯一值数量(8110)太多
#
# 开始处理列: ref_exons
# 数据类型: float64
# 唯一值数量: 104
# 非空值数量: 90920
# 处理数值型数据...
# 数据范围: 1.0 to 173.0
# 成功保存图片: check_column_distribution/ref_exons_distribution.png
#
# 开始处理列: diff_to_TSS
# 数据类型: float64
# 唯一值数量: 7473
# 非空值数量: 33700
# 跳过列 diff_to_TSS: 唯一值数量(7473)太多
#
# 开始处理列: diff_to_TTS
# 数据类型: float64
# 唯一值数量: 2455
# 非空值数量: 33700
# 跳过列 diff_to_TTS: 唯一值数量(2455)太多
#
# 开始处理列: diff_to_gene_TSS
# 数据类型: float64
# 唯一值数量: 8799
# 非空值数量: 90920
# 跳过列 diff_to_gene_TSS: 唯一值数量(8799)太多
#
# 开始处理列: diff_to_gene_TTS
# 数据类型: float64
# 唯一值数量: 5259
# 非空值数量: 90920
# 跳过列 diff_to_gene_TTS: 唯一值数量(5259)太多
#
# 开始处理列: subcategory
# 数据类型: object
# 唯一值数量: 11
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/subcategory_distribution.png
#
# 开始处理列: RTS_stage
# 数据类型: bool
# 唯一值数量: 2
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: False to True
# 成功保存图片: check_column_distribution/RTS_stage_distribution.png
#
# 开始处理列: all_canonical
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 89554
# 处理类别型数据...
# 成功保存图片: check_column_distribution/all_canonical_distribution.png
#
# 开始处理列: min_sample_cov
# 数据类型: float64
# 唯一值数量: 2
# 非空值数量: 89554
# 处理数值型数据...
# 数据范围: 0.0 to 1.0
# 成功保存图片: check_column_distribution/min_sample_cov_distribution.png
#
# 开始处理列: min_cov
# 数据类型: float64
# 唯一值数量: 33675
# 非空值数量: 89554
# 跳过列 min_cov: 唯一值数量(33675)太多
#
# 开始处理列: min_cov_pos
# 数据类型: object
# 唯一值数量: 63
# 非空值数量: 89554
# 处理类别型数据...
# 警告: min_cov_pos 包含超过20个唯一值，只显示前20个
# 成功保存图片: check_column_distribution/min_cov_pos_distribution.png
#
# 开始处理列: sd_cov
# 数据类型: float64
# 唯一值数量: 83008
# 非空值数量: 89554
# 跳过列 sd_cov: 唯一值数量(83008)太多
#
# 开始处理列: FL
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 FL: 没有有效数值数据
#
# 开始处理列: n_indels
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 n_indels: 没有有效数值数据
#
# 开始处理列: n_indels_junc
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 n_indels_junc: 没有有效数值数据
#
# 开始处理列: bite
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 89554
# 处理类别型数据...
# 成功保存图片: check_column_distribution/bite_distribution.png
#
# 开始处理列: iso_exp
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 iso_exp: 没有有效数值数据
#
# 开始处理列: gene_exp
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 gene_exp: 没有有效数值数据
#
# 开始处理列: ratio_exp
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 ratio_exp: 没有有效数值数据
#
# 开始处理列: FSM_class
# 数据类型: object
# 唯一值数量: 3
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/FSM_class_distribution.png
#
# 开始处理列: coding
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/coding_distribution.png
#
# 开始处理列: ORF_length
# 数据类型: float64
# 唯一值数量: 2231
# 非空值数量: 85705
# 跳过列 ORF_length: 唯一值数量(2231)太多
#
# 开始处理列: CDS_length
# 数据类型: float64
# 唯一值数量: 2235
# 非空值数量: 85705
# 跳过列 CDS_length: 唯一值数量(2235)太多
#
# 开始处理列: CDS_start
# 数据类型: float64
# 唯一值数量: 3708
# 非空值数量: 85705
# 跳过列 CDS_start: 唯一值数量(3708)太多
#
# 开始处理列: CDS_end
# 数据类型: float64
# 唯一值数量: 6044
# 非空值数量: 85705
# 跳过列 CDS_end: 唯一值数量(6044)太多
#
# 开始处理列: CDS_genomic_start
# 数据类型: float64
# 唯一值数量: 30321
# 非空值数量: 85705
# 跳过列 CDS_genomic_start: 唯一值数量(30321)太多
#
# 开始处理列: CDS_genomic_end
# 数据类型: float64
# 唯一值数量: 27674
# 非空值数量: 85705
# 跳过列 CDS_genomic_end: 唯一值数量(27674)太多
#
# 开始处理列: predicted_NMD
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 85068
# 处理类别型数据...
# 成功保存图片: check_column_distribution/predicted_NMD_distribution.png
#
# 开始处理列: perc_A_downstream_TTS
# 数据类型: float64
# 唯一值数量: 21
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: 0.0 to 100.0
# 成功保存图片: check_column_distribution/perc_A_downstream_TTS_distribution.png
#
# 开始处理列: seq_A_downstream_TTS
# 数据类型: object
# 唯一值数量: 34791
# 非空值数量: 90929
# 跳过列 seq_A_downstream_TTS: 唯一值数量(34791)太多
#
# 开始处理列: dist_to_CAGE_peak
# 数据类型: float64
# 唯一值数量: 6464
# 非空值数量: 81405
# 跳过列 dist_to_CAGE_peak: 唯一值数量(6464)太多
#
# 开始处理列: within_CAGE_peak
# 数据类型: bool
# 唯一值数量: 2
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: False to True
# 成功保存图片: check_column_distribution/within_CAGE_peak_distribution.png
#
# 开始处理列: dist_to_polyA_site
# 数据类型: float64
# 唯一值数量: 269
# 非空值数量: 77378
# 处理数值型数据...
# 数据范围: -153.0 to 167.0
# 成功保存图片: check_column_distribution/dist_to_polyA_site_distribution.png
#
# 开始处理列: within_polyA_site
# 数据类型: bool
# 唯一值数量: 2
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: False to True
# 成功保存图片: check_column_distribution/within_polyA_site_distribution.png
#
# 开始处理列: polyA_motif
# 数据类型: object
# 唯一值数量: 16
# 非空值数量: 78009
# 处理类别型数据...
# 成功保存图片: check_column_distribution/polyA_motif_distribution.png
#
# 开始处理列: polyA_dist
# 数据类型: float64
# 唯一值数量: 45
# 非空值数量: 78009
# 处理数值型数据...
# 数据范围: -45.0 to -1.0
# 成功保存图片: check_column_distribution/polyA_dist_distribution.png
#
# 开始处理列: polyA_motif_found
# 数据类型: bool
# 唯一值数量: 2
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: False to True
# 成功保存图片: check_column_distribution/polyA_motif_found_distribution.png
#
# 开始处理列: ORF_seq
# 数据类型: object
# 唯一值数量: 55090
# 非空值数量: 85705
# 跳过列 ORF_seq: 唯一值数量(55090)太多
#
# 开始处理列: ratio_TSS
# 数据类型: float64
# 唯一值数量: 0
# 非空值数量: 0
# 处理数值型数据...
# 跳过列 ratio_TSS: 没有有效数值数据
#
# 开始处理列: POS_MLprob
# 数据类型: float64
# 唯一值数量: 458
# 非空值数量: 89554
# 处理数值型数据...
# 数据范围: 0.0 to 1.0
# 成功保存图片: check_column_distribution/POS_MLprob_distribution.png
#
# 开始处理列: NEG_MLprob
# 数据类型: float64
# 唯一值数量: 458
# 非空值数量: 89554
# 处理数值型数据...
# 数据范围: 0.0 to 1.0
# 成功保存图片: check_column_distribution/NEG_MLprob_distribution.png
#
# 开始处理列: ML_classifier
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 89554
# 处理类别型数据...
# 成功保存图片: check_column_distribution/ML_classifier_distribution.png
#
# 开始处理列: intra_priming
# 数据类型: bool
# 唯一值数量: 2
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: False to True
# 成功保存图片: check_column_distribution/intra_priming_distribution.png
#
# 开始处理列: filter_result
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/filter_result_distribution.png
#
# 开始处理列: expressed_samples
# 数据类型: object
# 唯一值数量: 35013
# 非空值数量: 90929
# 跳过列 expressed_samples: 唯一值数量(35013)太多
#
# 开始处理列: subtype
# 数据类型: object
# 唯一值数量: 39
# 非空值数量: 89501
# 处理类别型数据...
# 警告: subtype 包含超过20个唯一值，只显示前20个
# 成功保存图片: check_column_distribution/subtype_distribution.png
#
# 开始处理列: specificity
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 90929
# 处理类别型数据...
# 成功保存图片: check_column_distribution/specificity_distribution.png
#
# 开始处理列: sample_no
# 数据类型: float64
# 唯一值数量: 35
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: 1.0 to 35.0
# 成功保存图片: check_column_distribution/sample_no_distribution.png
#
# 开始处理列: Localizations
# 数据类型: object
# 唯一值数量: 91
# 非空值数量: 52778
# 处理类别型数据...
# 警告: Localizations 包含超过20个唯一值，只显示前20个
# 成功保存图片: check_column_distribution/Localizations_distribution.png
#
# 开始处理列: symbol_rename
# 数据类型: object
# 唯一值数量: 79518
# 非空值数量: 90929
# 跳过列 symbol_rename: 唯一值数量(79518)太多
#
# 开始处理列: meanPSI
# 数据类型: float64
# 唯一值数量: 81450
# 非空值数量: 90915
# 跳过列 meanPSI: 唯一值数量(81450)太多
#
# 开始处理列: DetectionRate
# 数据类型: float64
# 唯一值数量: 894
# 非空值数量: 90929
# 处理数值型数据...
# 数据范围: 0.0 to 1.0
# 成功保存图片: check_column_distribution/DetectionRate_distribution.png
#
# 开始处理列: delta_PSI
# 数据类型: float64
# 唯一值数量: 73119
# 非空值数量: 86742
# 跳过列 delta_PSI: 唯一值数量(73119)太多
#
# 开始处理列: deltaPSI_p
# 数据类型: float64
# 唯一值数量: 1700
# 非空值数量: 86790
# 跳过列 deltaPSI_p: 唯一值数量(1700)太多
#
# 开始处理列: mane_id_x
# 数据类型: object
# 唯一值数量: 9226
# 非空值数量: 10701
# 跳过列 mane_id_x: 唯一值数量(9226)太多
#
# 开始处理列: orf_identity
# 数据类型: float64
# 唯一值数量: 1
# 非空值数量: 10701
# 处理数值型数据...
# 数据范围: 100.0 to 100.0
# 成功保存图片: check_column_distribution/orf_identity_distribution.png
#
# 开始处理列: cds_identity
# 数据类型: float64
# 唯一值数量: 88
# 非空值数量: 10271
# 处理数值型数据...
# 数据范围: 0.901 to 1.0
# 成功保存图片: check_column_distribution/cds_identity_distribution.png
#
# 开始处理列: gray_drug_cor
# 数据类型: float64
# 唯一值数量: 42492
# 非空值数量: 51166
# 跳过列 gray_drug_cor: 唯一值数量(42492)太多
#
# 开始处理列: gray_drug_p
# 数据类型: float64
# 唯一值数量: 38910
# 非空值数量: 51166
# 跳过列 gray_drug_p: 唯一值数量(38910)太多
#
# 开始处理列: ccle_drug_cor
# 数据类型: float64
# 唯一值数量: 32254
# 非空值数量: 51166
# 跳过列 ccle_drug_cor: 唯一值数量(32254)太多
#
# 开始处理列: ccle_drug_p
# 数据类型: float64
# 唯一值数量: 27798
# 非空值数量: 51166
# 跳过列 ccle_drug_p: 唯一值数量(27798)太多
#
# 开始处理列: combined_cor
# 数据类型: float64
# 唯一值数量: 50893
# 非空值数量: 51166
# 跳过列 combined_cor: 唯一值数量(50893)太多
#
# 开始处理列: combined_p
# 数据类型: float64
# 唯一值数量: 50791
# 非空值数量: 51166
# 跳过列 combined_p: 唯一值数量(50791)太多
#
# 开始处理列: drug_response.x
# 数据类型: object
# 唯一值数量: 2
# 非空值数量: 723
# 处理类别型数据...
# 成功保存图片: check_column_distribution/drug_response.x_distribution.png
#
# 开始处理列: log2foldChange
# 数据类型: float64
# 唯一值数量: 10682
# 非空值数量: 10691
# 跳过列 log2foldChange: 唯一值数量(10682)太多
#
# 开始处理列: pValues
# 数据类型: float64
# 唯一值数量: 6318
# 非空值数量: 10691
# 跳过列 pValues: 唯一值数量(6318)太多
#
# 开始处理列: FDR
# 数据类型: float64
# 唯一值数量: 4801
# 非空值数量: 10691
# 跳过列 FDR: 唯一值数量(4801)太多
#
# 开始处理列: fusion_log2foldChange
# 数据类型: float64
# 唯一值数量: 48497
# 非空值数量: 48548
# 跳过列 fusion_log2foldChange: 唯一值数量(48497)太多
#
# 开始处理列: fusion_pValues
# 数据类型: float64
# 唯一值数量: 13185
# 非空值数量: 48548
# 跳过列 fusion_pValues: 唯一值数量(13185)太多
#
# 开始处理列: fusion_FDR
# 数据类型: float64
# 唯一值数量: 9616
# 非空值数量: 48548
# 跳过列 fusion_FDR: 唯一值数量(9616)太多
#
# 开始处理列: org_drug_cor
# 数据类型: float64
# 唯一值数量: 3274
# 非空值数量: 71692
# 跳过列 org_drug_cor: 唯一值数量(3274)太多
#
# 开始处理列: org_drug_p
# 数据类型: float64
# 唯一值数量: 2282
# 非空值数量: 71692
# 跳过列 org_drug_p: 唯一值数量(2282)太多
#
# 开始处理列: Pfam
# 数据类型: object
# 唯一值数量: 4935
# 非空值数量: 28983
# 跳过列 Pfam: 唯一值数量(4935)太多
#
# 开始处理列: Gene Ontology (biological process)
# 数据类型: object
# 唯一值数量: 10472
# 非空值数量: 28983
# 跳过列 Gene Ontology (biological process): 唯一值数量(10472)太多
#
# 开始处理列: Gene Ontology (molecular function)
# 数据类型: object
# 唯一值数量: 7347
# 非空值数量: 28983
# 跳过列 Gene Ontology (molecular function): 唯一值数量(7347)太多
#
# 开始处理列: Gene Ontology (cellular component)
# 数据类型: object
# 唯一值数量: 8265
# 非空值数量: 28983
# 跳过列 Gene Ontology (cellular component): 唯一值数量(8265)太多
#
# 开始处理列: Gene3D
# 数据类型: object
# 唯一值数量: 2756
# 非空值数量: 28983
# 跳过列 Gene3D: 唯一值数量(2756)太多
#
# 开始处理列: EC number
# 数据类型: object
# 唯一值数量: 1836
# 非空值数量: 28983
# 跳过列 EC number: 唯一值数量(1836)太多
#
# 开始处理列: singleton
# 数据类型: object
# 唯一值数量: 1
# 非空值数量: 6680
# 处理类别型数据...
# 成功保存图片: check_column_distribution/singleton_distribution.png
#
# 处理完成！
